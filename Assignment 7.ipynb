# %% [markdown]
# # Setting up the development environment by importing required libraries and modules:
# 1. Numpy: It will provide the support for efficient numerical computation.
# 2. Pandas: It is convenient library that supports dataframes. Working with pandas will bring ease in many crucial data    o   o    operations.
# 3. Matplotlib: It provides a MATLAB-like plotting framework.
# 4. Seaborn: It is a visualization library based on matplotlib which provides a high-level interface for drawing attractive  s      statistical graphics.
# 5. Sklearn: It is python library for data mining, data analysis and machine learning

# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Loading Libraries

# %%
red=pd.read_csv('winequality-red.csv',sep=';')

# %% [markdown]
# # Getting to know your data

# %%
print(red.shape)
# Out:
# (1599, 12)

# %% [markdown]
# From above lines we can learn that there are total 1599 observations with 12 different feature variables/attributes present in the Red Wine dataset.

# %%
red.index
# Out:
# RangeIndex(start=0, stop=1599, step=1)

# %%
red.columns
# Out:
# Index([u'fixed acidity', u'volatile acidity', u'citric acid',
#        u'residual sugar', u'chlorides', u'free sulfur dioxide',
#        u'total sulfur dioxide', u'density', u'pH', u'sulphates', u'alcohol',
#        u'quality'],
#       dtype='object')

# %%
red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# . We can see that, all 12 columns are of numeric data types. Out of 12 variables, 11 are predictor variables and last one 'quality' is an response variable.

# %%
red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# The Red wine quality Dataset:
#
# Involves predicting the onset of quality within Red_Wine given details.
# It is a binary (2-class) classification problem.
# The number of observations for each class is not balanced.
# There are 768 observations with 9 input variables and 1 output variable.
#
# The variable names are as follows:
#
# About the Data set
# The data set contains 1,599 observations on Red Wines. There are 12 different variables to describe a wine. Each variable is
#
# 1. Fixed Acidity: most acids involved with wine or fixed or nonvolatile (do not evaporate readily)
#
# 2. Volatile Acidity: the amount of acetic acid in wine, which at too high of levels can lead to an unpleasant, vinegar taste
#
# 3. Citric Acid: found in small quantities, citric acid can add 'freshness' and flavor to wines.
#
# 4. Residual Sugar: the amount of sugar remaining after fermentation stops, it's rare to find wines with less than 1 gram/liter      and wines with greater than 45 grams/liter are considered sweet.
#
# 5. Chlorides: the amount of salt in the wine.
#
# 6. Free Sulfur Dioxide: the free form of SO2 exists in equilibrium between molecular SO2 (as a dissolved gas) and bisulfite ion;    it prevents microbial growth and the oxidation of wine.
#
# 7. Total Sulfur Dioxide: amount of free and bound forms of S02; in low concentrations, SO2 is mostly undetectable in wine, but      at free SO2 concentrations over 50 ppm, SO2 becomes evident in the nose and taste of wine.
#
# 8. Density: the density of water is close to that of water depending on the percent alcohol and sugar content.
#
# 9. pH: describes how acidic or basic a wine is on a scale from 0 (very acidic) to 14 (very basic); most wines are between 3-4 on    the pH scale.
#
# 10. Sulphates: a wine additive which can contribute to sulfur dioxide gas (S02) levels, which acts as an antimicrobial and           antioxidant.
#
# 11. Alcohol: the percent alcohol content of the wine
#
# 12. Quality: score between 0 and 10
#
# Variable classification:
#
# Quantitative:
#
#     1. Fixed Acidity: most acids involved with wine.
#
#     2. Volatile Acidity: the amount of acetic acid in wine.
#
#     3. Citric Acid: found in small quantities.
#
#     4. Residual Sugar: the amount of sugar remaining after fermentation stops.
#
#     5. Chlorides: the amount of salt in the wine.
#
#     6. Free Sulfur Dioxide: it prevents microbial growth and the oxidation of wine.
#
#     7. Total Sulfur Dioxide: amount of free and bound forms of S02. SO2 becomes evident in the nose and taste of wine.
#
#     8. Density: the density of water is close to that of water depending on the percent alcohol and sugar content.
#
#     9. pH: describes how acidic or basic a wine is on a scale from 0 (very acidic) to 14 (very basic).
#
#     10. Sulphates: a wine additive which can contribute to sulfur dioxide gas (S02) levels.
#
#     11. Alcohol: the percent alcohol content of the wine
#
# Categorical:
#
#     12. Quality: score between 0 and 10

# %% [markdown]
# # Let's look for the missing values in red wine dataset:

# %%
red.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# The red wine dataset doesn't have any missing values/rows/cells for any of the variables/feature.
#
# It seems that data has been collected neatly or prior cleaning has been performed before publishing the dataset

# %% [markdown]
# # Making univairate graph
#
# Statistical Analysis
#
# 1. It includes finding the central tendencies like mean, median, mode, frequency table, range, std deviation etc.
# 2. Distribution of individual variables.
#
# Graphical Analysis
#
# 1. Histogram
# 2. KDE Plot
# 3. Box Plot
# 4. Violin Plot

# %%
# Let's look at the summary of the dataset
red.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# The summary of Red Wine dataset looks perfect, there is no visible abnormality in data (invalid/negative values).
#
# All the data seems to be in range (with different scales, which needs standardization).

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.distplot(red['fixed acidity'],kde=False,color='red')
plt.subplot(2,2,2)
sns.kdeplot(red['fixed acidity'],shade=True,color='black')
plt.subplot(2,2,3)
sns.boxplot(red['fixed acidity'],color='purple')
plt.subplot(2,2,4)
sns.violinplot(red['fixed acidity'],color='navy')
# Out:
# C:\Users\mikkujain\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.distplot(red['volatile acidity'],kde=False,color='green')
plt.subplot(2,2,2)
sns.kdeplot(red['volatile acidity'],shade=True,color='black')
plt.subplot(2,2,3)
sns.boxplot(red['volatile acidity'],color='orange')
plt.subplot(2,2,4)
sns.violinplot(red['volatile acidity'],color='blue')
# Out:
# C:\Users\mikkujain\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.distplot(red['citric acid'],kde=False,color='orange')
plt.subplot(2,2,2)
sns.kdeplot(red['citric acid'],shade=True,color='k')
plt.subplot(2,2,3)
sns.boxplot(red['citric acid'],color='black')
plt.subplot(2,2,4)
sns.violinplot(red['citric acid'],color='purple')
# Out:
# C:\Users\mikkujain\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.distplot(red['residual sugar'],kde=False,color='red')
plt.subplot(2,2,2)
sns.kdeplot(red['residual sugar'],shade=True,color='black')
plt.subplot(2,2,3)
sns.boxplot(red['residual sugar'],color='purple')
plt.subplot(2,2,4)
sns.violinplot(red['residual sugar'],color='green')
# Out:
# C:\Users\mikkujain\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.distplot(red['chlorides'],kde=False,color='red')
plt.subplot(2,2,2)
sns.kdeplot(red['chlorides'],shade=True,color='green')
plt.subplot(2,2,3)
sns.boxplot(red['chlorides'],color='grey')
plt.subplot(2,2,4)
sns.violinplot(red['chlorides'],color='black')
# Out:
# C:\Users\mikkujain\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.distplot(red['free sulfur dioxide'],kde=False,color='green')
plt.subplot(2,2,2)
sns.kdeplot(red['free sulfur dioxide'],shade=True,color='black')
plt.subplot(2,2,3)
sns.boxplot(red['free sulfur dioxide'],color='orange')
plt.subplot(2,2,4)
sns.violinplot(red['free sulfur dioxide'],color='blue')
# Out:
# C:\Users\mikkujain\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.distplot(red['total sulfur dioxide'],kde=False,color='orange')
plt.subplot(2,2,2)
sns.kdeplot(red['total sulfur dioxide'],shade=True,color='k')
plt.subplot(2,2,3)
sns.boxplot(red['total sulfur dioxide'],color='black')
plt.subplot(2,2,4)
sns.violinplot(red['total sulfur dioxide'],color='purple')
# Out:
# C:\Users\mikkujain\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.distplot(red['density'],kde=False,color='red')
plt.subplot(2,2,2)
sns.kdeplot(red['density'],shade=True,color='black')
plt.subplot(2,2,3)
sns.boxplot(red['density'],color='purple')
plt.subplot(2,2,4)
sns.violinplot(red['density'],color='navy')
# Out:
# C:\Users\mikkujain\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.distplot(red['pH'],kde=False,color='red')
plt.subplot(2,2,2)
sns.kdeplot(red['pH'],shade=True,color='green')
plt.subplot(2,2,3)
sns.boxplot(red['pH'],color='grey')
plt.subplot(2,2,4)
sns.violinplot(red['pH'],color='black')
# Out:
# C:\Users\mikkujain\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.distplot(red['sulphates'],kde=False,color='red')
plt.subplot(2,2,2)
sns.kdeplot(red['sulphates'],shade=True,color='black')
plt.subplot(2,2,3)
sns.boxplot(red['sulphates'],color='purple')
plt.subplot(2,2,4)
sns.violinplot(red['sulphates'],color='navy')
# Out:
# C:\Users\mikkujain\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.distplot(red['alcohol'],kde=False,color='green')
plt.subplot(2,2,2)
sns.kdeplot(red['alcohol'],shade=True,color='black')
plt.subplot(2,2,3)
sns.boxplot(red['alcohol'],color='orange')
plt.subplot(2,2,4)
sns.violinplot(red['alcohol'],color='blue')
# Out:
# C:\Users\mikkujain\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
red['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
sns.countplot(red['quality'])

# %% [markdown]
# # Bivarte graph

# %%
sns.pairplot(red,hue='quality')

# %% [markdown]
# # Multivariate graph

# %% [markdown]
# # Corelation between features/variables:
#
# Let's check the corelation between the target variable and predictor variables,

# %%
corr_matrix=red.corr()
plt.figure(figsize=(12, 5))
sns.heatmap(corr_matrix,annot=True, linewidths=0, vmin=-1, cmap="RdBu_r")

# %%
corr_matrix['quality'].sort_values(ascending=False)
# Out:
# quality                 1.000000
# alcohol                 0.476166
# sulphates               0.251397
# citric acid             0.226373
# fixed acidity           0.124052
# residual sugar          0.013732
# free sulfur dioxide    -0.050656
# pH                     -0.057731
# chlorides              -0.128907
# density                -0.174919
# total sulfur dioxide   -0.185100
# volatile acidity       -0.390558
# Name: quality, dtype: float64

# %% [markdown]
# We can observe that, the 'alcohol, sulphates, citric_acid & fixed_acidity' have maximum corelation with response variable 'quality'.
#
# This means that, they need to be further analysed for detailed pattern and corelation exploration. Hence, we will use only these 4 variables in our future analysis

# %% [markdown]
# # Analysis of alcohol percentage with wine quality:

# %%
bx = sns.boxplot(x="quality", y='alcohol', data = red)
bx.set(xlabel='Wine Quality', ylabel='Alcohol Percent', title='Alcohol percent in different wine quality types')
# Out:
# [Text(0,0.5,'Alcohol Percent'),
#  Text(0.5,0,'Wine Quality'),
#  Text(0.5,1,'Alcohol percent in different wine quality types')]

# %% [markdown]
# # Analysis of sulphates & wine ratings:

# %%
bx = sns.boxplot(x="quality", y='sulphates', data = red)
bx.set(xlabel='Wine Ratings', ylabel='Sulphates', title='Sulphates in different types of Wine ratings')
# Out:
# [Text(0,0.5,'Sulphates'),
#  Text(0.5,0,'Wine Ratings'),
#  Text(0.5,1,'Sulphates in different types of Wine ratings')]

# %%
sns.stripplot(x="quality", y="fixed acidity", data=red,hue="quality", jitter=True)

# %%
sns.stripplot(x="quality", y="volatile acidity", data=red,hue="quality", jitter=True)

# %%
sns.stripplot(x="quality", y="citric acid", data=red,hue="quality", jitter=True)

# %%
sns.stripplot(x="quality", y="residual sugar", data=red,hue="quality", jitter=True)

# %%
sns.stripplot(x="quality", y="free sulfur dioxide", data=red,hue="quality", jitter=True)

# %%
sns.stripplot(x="quality", y="total sulfur dioxide", data=red,hue="quality", jitter=True)

# %%
sns.stripplot(x="quality", y="density", data=red,hue="quality", jitter=True)

# %%
sns.stripplot(x="quality", y="pH", data=red,hue="quality", jitter=True)

# %%
sns.stripplot(x="quality", y="sulphates", data=red,hue="quality", jitter=True)

# %%
sns.stripplot(x="quality", y="alcohol", data=red,hue="quality", jitter=True)

# %% [markdown]
# # Make swarmplot

# %%
sns.swarmplot(x="quality", y="fixed acidity", data=red,hue='quality')

# %%
sns.swarmplot(x="quality", y="volatile acidity", data=red,hue='quality')

# %%
sns.swarmplot(x="quality", y="citric acid", data=red,hue='quality')

# %%
sns.swarmplot(x="quality", y="residual sugar", data=red,hue='quality')

# %%
sns.swarmplot(x="quality", y="chlorides", data=red,hue='quality')

# %%
sns.swarmplot(x="quality", y="free sulfur dioxide", data=red,hue='quality')

# %%
sns.swarmplot(x="quality", y="total sulfur dioxide", data=red,hue='quality')

# %%
sns.swarmplot(x="quality", y="pH", data=red,hue='quality')

# %%
sns.swarmplot(x="quality", y="density", data=red,hue='quality')

# %%
sns.swarmplot(x="quality", y="sulphates", data=red,hue='quality')

# %%
sns.swarmplot(x="quality", y="alcohol", data=red,hue='quality')

# %% [markdown]
# # Using Logisitic Regression to find the accuracy of red wine

# %% [markdown]
# # First spilit the data into train and test

# %%
from sklearn.model_selection import train_test_split as tts
train, test=tts(red,test_size=0.2,random_state=42)

# %%
train_x=train.loc[:, train.columns !="quality"]
test_x=test.loc[:, train.columns !="quality"]

train_y=train["quality"]
test_y=test['quality']

# %% [markdown]
# # making logistic alogithim

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(train_x, train_y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# # To predict the result

# %%
test_pred = lr.predict(test_x)

# %%
result=pd.DataFrame({'Actual Score':test_y,'predicted_score':test_pred})
print(result)
# Out:
#       Actual Score  predicted_score
# 803              6                5
# 124              5                5
# 350              6                6
# 682              5                5
# 1326             6                6
# 976              5                5
# 1493             5                5
# 706              5                5
# 613              5                6
# 1587             6                6
# 513              7                6
# 1505             3                5
# 1525             5                6
# 1568             5                5
# 220              6                5
# 1010             7                6
# 30               5                5
# 942              7                5
# 481              8                7
# 135              5                5
# 65               5                5
# 99               6                5
# 1547             5                6
# 1311             6                6
# 29               6                5
# ...

# %%
#Computing Mean Squared Error 
from sklearn.metrics import mean_squared_error, mean_absolute_error
print(mean_squared_error(test_y, test_pred)*100)
print(mean_absolute_error(test_y, test_pred)*100)
# Out:
# 49.6875
# 45.3125

# %%
#Computing r2 Score
from sklearn.metrics import r2_score
print(r2_score(test_y, test_pred)*100)
# Out:
# 23.96778194533691

# %%
#Computing accuaracy Score
from sklearn.metrics import accuracy_score
accuracy_score(test_y,test_pred)
# Out:
# 0.56875

# %% [markdown]
# # Conclusions

# %% [markdown]
# We observed the key factors that determine and affects the quality of the red wine. Wine quality is ultimately a subjective measure.
#
# To make predictions of wine quality and any other if required, we trained one models.
# As seen, the sklearn's Linear Regression model.
#
# The usage of this analysis will help to understand whether by modifying the variables, it is possible to increase the quality of the wine on the market.
# If you can control your variables, then you can predict the quality of your wine and obtain more profits.
